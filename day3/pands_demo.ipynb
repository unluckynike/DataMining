# %% [markdown]
# #### Pandas介绍
#     - 数据处理工具
#     - panel + data + analysis
#     - panel面板数据 - 计量经济学 三维数据
# #### 为什么使用Pandas
#     - 便捷的数据处理能力
#     - 读取文件方便
#     - 封装了Matplotlib、Numpy的画图和计算
# ![](./img/20221010144823.png)

# %%
import numpy as np
# 创建一个符合正态分布的10个股票5天的涨跌幅数据
stock_change = np.random.normal(0, 1, (10, 5))

# %%
stock_change
# Out:
# array([[-1.14036878,  0.52822625, -1.99030181,  0.32200462, -0.88009635],
#        [-0.36859969, -0.77665818,  1.05503916, -0.92739055, -1.34968215],
#        [ 0.0421284 ,  1.07719851, -0.17115297,  0.46708798, -1.29237743],
#        [ 1.30654022, -1.36486177,  0.37566037, -0.60072134,  0.83254801],
#        [-0.10182441, -0.44687089,  0.14813582, -0.54987693, -1.04086233],
#        [-0.96820763, -0.23222622, -0.47372388, -0.03601228,  0.50072565],
#        [ 0.99896086, -1.51978944,  0.16868777, -0.6354992 ,  0.30232644],
#        [ 0.59642945, -0.78917551, -0.07435049, -0.50069606, -0.84525642],
#        [-1.14436772,  0.23975373, -0.80234126, -0.6186902 ,  0.15868353],
#        [ 0.98701825, -0.81602394, -0.57321911,  1.44455894,  0.35380343]])

# %%
import pandas as pd

# %% [markdown]
# #### DataFrame
#    - 结构：既有行索引，又有列索引的二维数组
#    - 属性：
#      - shape
#      - index
#      - columns
#      - values
#      -  T
#    - 方法：
#      - head()
#      - tail()
#    - DataFrame索引的设置
#      - 修改行列索引值
#      - 重设索引
#      - 设置新索引
#    - Panel
#      - DataFrame的容器
#    - Series
#      - 带索引的一维数组
#      - 属性
#        - index
#        - values
#
# #### 总结：
#    - DataFrame是Series的容器
#    - Panel是DataFrame的容器

# %%
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4
# 0 -1.140369  0.528226 -1.990302  0.322005 -0.880096
# 1 -0.368600 -0.776658  1.055039 -0.927391 -1.349682
# 2  0.042128  1.077199 -0.171153  0.467088 -1.292377
# 3  1.306540 -1.364862  0.375660 -0.600721  0.832548
# 4 -0.101824 -0.446871  0.148136 -0.549877 -1.040862
# 5 -0.968208 -0.232226 -0.473724 -0.036012  0.500726
# 6  0.998961 -1.519789  0.168688 -0.635499  0.302326
# 7  0.596429 -0.789176 -0.074350 -0.500696 -0.845256
# 8 -1.144368  0.239754 -0.802341 -0.618690  0.158684
# 9  0.987018 -0.816024 -0.573219  1.444559  0.353803

# %%
# 添加行索引
stock=["股票{}".format(i) for i in range(10)]

# %%
pd.DataFrame(stock_change,index=stock)
# Out:
#             0         1         2         3         4
# 股票0 -1.140369  0.528226 -1.990302  0.322005 -0.880096
# 股票1 -0.368600 -0.776658  1.055039 -0.927391 -1.349682
# 股票2  0.042128  1.077199 -0.171153  0.467088 -1.292377
# 股票3  1.306540 -1.364862  0.375660 -0.600721  0.832548
# 股票4 -0.101824 -0.446871  0.148136 -0.549877 -1.040862
# 股票5 -0.968208 -0.232226 -0.473724 -0.036012  0.500726
# 股票6  0.998961 -1.519789  0.168688 -0.635499  0.302326
# 股票7  0.596429 -0.789176 -0.074350 -0.500696 -0.845256
# 股票8 -1.144368  0.239754 -0.802341 -0.618690  0.158684
# 股票9  0.987018 -0.816024 -0.573219  1.444559  0.353803

# %%
# 添加列索引
data=pd.date_range(start="20221010",periods=5,freq="B")

# %%
data
# Out:
# DatetimeIndex(['2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#                '2022-10-14'],
#               dtype='datetime64[ns]', freq='B')

# %%
data=pd.DataFrame(stock_change,index=stock,columns=data)

# %%
data
# Out:
#      2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票0   -1.140369    0.528226   -1.990302    0.322005   -0.880096
# 股票1   -0.368600   -0.776658    1.055039   -0.927391   -1.349682
# 股票2    0.042128    1.077199   -0.171153    0.467088   -1.292377
# 股票3    1.306540   -1.364862    0.375660   -0.600721    0.832548
# 股票4   -0.101824   -0.446871    0.148136   -0.549877   -1.040862
# 股票5   -0.968208   -0.232226   -0.473724   -0.036012    0.500726
# 股票6    0.998961   -1.519789    0.168688   -0.635499    0.302326
# 股票7    0.596429   -0.789176   -0.074350   -0.500696   -0.845256
# 股票8   -1.144368    0.239754   -0.802341   -0.618690    0.158684
# 股票9    0.987018   -0.816024   -0.573219    1.444559    0.353803

# %% [markdown]
# #### dataFram的属性

# %%
data # 10行5列
# Out:
#      2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票0   -1.140369    0.528226   -1.990302    0.322005   -0.880096
# 股票1   -0.368600   -0.776658    1.055039   -0.927391   -1.349682
# 股票2    0.042128    1.077199   -0.171153    0.467088   -1.292377
# 股票3    1.306540   -1.364862    0.375660   -0.600721    0.832548
# 股票4   -0.101824   -0.446871    0.148136   -0.549877   -1.040862
# 股票5   -0.968208   -0.232226   -0.473724   -0.036012    0.500726
# 股票6    0.998961   -1.519789    0.168688   -0.635499    0.302326
# 股票7    0.596429   -0.789176   -0.074350   -0.500696   -0.845256
# 股票8   -1.144368    0.239754   -0.802341   -0.618690    0.158684
# 股票9    0.987018   -0.816024   -0.573219    1.444559    0.353803

# %%
data.shape
# Out:
# (10, 5)

# %%
data.index
# Out:
# Index(['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9'], dtype='object')

# %%
data.columns
# Out:
# DatetimeIndex(['2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#                '2022-10-14'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.values
# Out:
# array([[-1.14036878,  0.52822625, -1.99030181,  0.32200462, -0.88009635],
#        [-0.36859969, -0.77665818,  1.05503916, -0.92739055, -1.34968215],
#        [ 0.0421284 ,  1.07719851, -0.17115297,  0.46708798, -1.29237743],
#        [ 1.30654022, -1.36486177,  0.37566037, -0.60072134,  0.83254801],
#        [-0.10182441, -0.44687089,  0.14813582, -0.54987693, -1.04086233],
#        [-0.96820763, -0.23222622, -0.47372388, -0.03601228,  0.50072565],
#        [ 0.99896086, -1.51978944,  0.16868777, -0.6354992 ,  0.30232644],
#        [ 0.59642945, -0.78917551, -0.07435049, -0.50069606, -0.84525642],
#        [-1.14436772,  0.23975373, -0.80234126, -0.6186902 ,  0.15868353],
#        [ 0.98701825, -0.81602394, -0.57321911,  1.44455894,  0.35380343]])

# %%
data.T
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2022-10-10 -1.140369 -0.368600  0.042128  1.306540 -0.101824 -0.968208
# 2022-10-11  0.528226 -0.776658  1.077199 -1.364862 -0.446871 -0.232226
# 2022-10-12 -1.990302  1.055039 -0.171153  0.375660  0.148136 -0.473724
# 2022-10-13  0.322005 -0.927391  0.467088 -0.600721 -0.549877 -0.036012
# 2022-10-14 -0.880096 -1.349682 -1.292377  0.832548 -1.040862  0.500726
#
#                  股票6       股票7       股票8       股票9
# 2022-10-10  0.998961  0.596429 -1.144368  0.987018
# 2022-10-11 -1.519789 -0.789176  0.239754 -0.816024
# 2022-10-12  0.168688 -0.074350 -0.802341 -0.573219
# 2022-10-13 -0.635499 -0.500696 -0.618690  1.444559
# 2022-10-14  0.302326 -0.845256  0.158684  0.353803

# %%
data.head(3)
# Out:
#      2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票0   -1.140369    0.528226   -1.990302    0.322005   -0.880096
# 股票1   -0.368600   -0.776658    1.055039   -0.927391   -1.349682
# 股票2    0.042128    1.077199   -0.171153    0.467088   -1.292377

# %%
data.tail(2)
# Out:
#      2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票8   -1.144368    0.239754   -0.802341   -0.618690    0.158684
# 股票9    0.987018   -0.816024   -0.573219    1.444559    0.353803

# %% [markdown]
# #### DataFram索引的设置

# %%
data.head()
# Out:
#      2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票0   -1.140369    0.528226   -1.990302    0.322005   -0.880096
# 股票1   -0.368600   -0.776658    1.055039   -0.927391   -1.349682
# 股票2    0.042128    1.077199   -0.171153    0.467088   -1.292377
# 股票3    1.306540   -1.364862    0.375660   -0.600721    0.832548
# 股票4   -0.101824   -0.446871    0.148136   -0.549877   -1.040862

# %%
# data.index[2] = "股票88" 不能单独修改索引 只能整体修改

# %%
stock_=["股票——{}".format(i) for i in range(10)]

# %%
stock_
# Out:
# ['股票——0',
#  '股票——1',
#  '股票——2',
#  '股票——3',
#  '股票——4',
#  '股票——5',
#  '股票——6',
#  '股票——7',
#  '股票——8',
#  '股票——9']

# %%
data.index=stock_

# %%
data
# Out:
#        2022-10-10  2022-10-11  2022-10-12  2022-10-13  2022-10-14
# 股票——0   -1.140369    0.528226   -1.990302    0.322005   -0.880096
# 股票——1   -0.368600   -0.776658    1.055039   -0.927391   -1.349682
# 股票——2    0.042128    1.077199   -0.171153    0.467088   -1.292377
# 股票——3    1.306540   -1.364862    0.375660   -0.600721    0.832548
# 股票——4   -0.101824   -0.446871    0.148136   -0.549877   -1.040862
# 股票——5   -0.968208   -0.232226   -0.473724   -0.036012    0.500726
# 股票——6    0.998961   -1.519789    0.168688   -0.635499    0.302326
# 股票——7    0.596429   -0.789176   -0.074350   -0.500696   -0.845256
# 股票——8   -1.144368    0.239754   -0.802341   -0.618690    0.158684
# 股票——9    0.987018   -0.816024   -0.573219    1.444559    0.353803

# %%
data.index
# Out:
# Index(['股票——0', '股票——1', '股票——2', '股票——3', '股票——4', '股票——5', '股票——6', '股票——7',
#        '股票——8', '股票——9'],
#       dtype='object')

# %% [markdown]
# #### 重设索引

# %%
data.reset_index()
# Out:
#    index  2022-10-10 00:00:00  2022-10-11 00:00:00  2022-10-12 00:00:00  \
# 0  股票——0            -1.140369             0.528226            -1.990302
# 1  股票——1            -0.368600            -0.776658             1.055039
# 2  股票——2             0.042128             1.077199            -0.171153
# 3  股票——3             1.306540            -1.364862             0.375660
# 4  股票——4            -0.101824            -0.446871             0.148136
# 5  股票——5            -0.968208            -0.232226            -0.473724
# 6  股票——6             0.998961            -1.519789             0.168688
# 7  股票——7             0.596429            -0.789176            -0.074350
# 8  股票——8            -1.144368             0.239754            -0.802341
# 9  股票——9             0.987018            -0.816024            -0.573219
#
#    2022-10-13 00:00:00  2022-10-14 00:00:00
# 0             0.322005            -0.880096
# 1            -0.927391            -1.349682
# ...

# %%
data.reset_index().shape
# Out:
# (10, 6)

# %%
data.reset_index(drop=False)
# Out:
#    index  2022-10-10 00:00:00  2022-10-11 00:00:00  2022-10-12 00:00:00  \
# 0  股票——0            -1.140369             0.528226            -1.990302
# 1  股票——1            -0.368600            -0.776658             1.055039
# 2  股票——2             0.042128             1.077199            -0.171153
# 3  股票——3             1.306540            -1.364862             0.375660
# 4  股票——4            -0.101824            -0.446871             0.148136
# 5  股票——5            -0.968208            -0.232226            -0.473724
# 6  股票——6             0.998961            -1.519789             0.168688
# 7  股票——7             0.596429            -0.789176            -0.074350
# 8  股票——8            -1.144368             0.239754            -0.802341
# 9  股票——9             0.987018            -0.816024            -0.573219
#
#    2022-10-13 00:00:00  2022-10-14 00:00:00
# 0             0.322005            -0.880096
# 1            -0.927391            -1.349682
# ...

# %% [markdown]
# #### 设置新索引

# %%
df=pd.DataFrame({'month':[1,4,7,10],
                 'year':[2022,2021,2020,2019],
                 'sale':[55,77,22,45]})

# %%
df
# Out:
#    month  year  sale
# 0      1  2022    55
# 1      4  2021    77
# 2      7  2020    22
# 3     10  2019    45

# %%
# 设置月份为新的索引
df.set_index('month',drop=False) #drop 设置是否扔掉month列
# Out:
#        month  year  sale
# month
# 1          1  2022    55
# 4          4  2021    77
# 7          7  2020    22
# 10        10  2019    45

# %%
df.set_index('month',drop=False).index
# Out:
# Int64Index([1, 4, 7, 10], dtype='int64', name='month')

# %%
# 设置多个索引
new_df=df.set_index(['month','year'])

# %%
new_df
# Out:
#             sale
# month year
# 1     2022    55
# 4     2021    77
# 7     2020    22
# 10    2019    45

# %%
new_df.index
# Out:
# MultiIndex([( 1, 2022),
#             ( 4, 2021),
#             ( 7, 2020),
#             (10, 2019)],
#            names=['month', 'year'])

# %%
new_df.index.names
# Out:
# FrozenList(['month', 'year'])

# %%
new_df.index.levels # 每个level的元组值
# Out:
# FrozenList([[1, 4, 7, 10], [2019, 2020, 2021, 2022]])

# %% [markdown]
# #### panel

# %%
p = pd.Panel(np.arange(24).reshape(4,3,2),
                 items=list('ABCD'),
                 major_axis=pd.date_range('20130101', periods=3),
                 minor_axis=['first', 'second'])
# 新版已移除
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 p = pd.Panel(np.arange(24).reshape(4,3,2),
#       2                  items=list('ABCD'),
#       3                  major_axis=pd.date_range('20130101', periods=3),
#       4                  minor_axis=['first', 'second'])
#
# File ~/opt/anaconda3/envs/torchEnv/lib/python3.8/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 1.4.3
# 1.21.5

# %%
# !pip3 install pandas==0.24

# %% [markdown]
# #### Series

# %%
sr=data.iloc[1,:]   # index value

# %%
sr
# Out:
# 2022-10-10   -0.368600
# 2022-10-11   -0.776658
# 2022-10-12    1.055039
# 2022-10-13   -0.927391
# 2022-10-14   -1.349682
# Freq: B, Name: 股票——1, dtype: float64

# %%
sr.index
# Out:
# DatetimeIndex(['2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#                '2022-10-14'],
#               dtype='datetime64[ns]', freq='B')

# %%
sr.values
# Out:
# array([-0.36859969, -0.77665818,  1.05503916, -0.92739055, -1.34968215])

# %%
type(sr.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
type(sr.values)
# Out:
# numpy.ndarray

# %%
#  创建Series
pd.Series(np.arange(3,9,2),index=["a","b","c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int64

# %%
pd.Series({'red':100,'blue':200,'green':500,'yellow':1000})
# Out:
# red        100
# blue       200
# green      500
# yellow    1000
# dtype: int64

# %% [markdown]
# #### 基本数据操作
#    - 索引操作
#      1. 直接索引
#         - 先列后行
#      2. 按名字索引
#         - loc
#      3. 按数字索引
#         - iloc
#      4. 组合索引
#         - 数字、名字
#    - 排序
#      1. 对内容排序
#         - dataframe
#         - series
#      2. 对索引排序
#         - dataframe
#         - series

# %%
# 读取一个真实的股票实例
data=pd.read_csv("./stock_day/stock_day.csv")

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
# 删除一些列，让数据更简单些
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# ...

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
# 直接索引 先列后行
data["open"]["2018-02-26"]
# Out:
# 22.8

# %%
data["close"]["2018-02-26"]
# Out:
# 23.53

# %%
# data["2018-02-26"]["close"] # 先行后列则报错

# %%
# 按名字索引
data.loc["2018-02-26"]["close"]
# Out:
# 23.53

# %%
data.loc["2018-02-26", "open"]
# Out:
# 22.8

# %%
# 数字索引
data.iloc[1,0]
# Out:
# 22.8

# %%
# 组合索引
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
data.ix[:4, ['open', 'close', 'high', 'low']]
# 已经不再使用
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [61], in <cell line: 3>()
#       1 # 组合索引
#       2 # 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
# ----> 3 data.ix[:4, ['open', 'close', 'high', 'low']]
#
# File ~/opt/anaconda3/envs/torchEnv/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %% [markdown]
# #### 赋值操作

# %%
data

# %%
data.open=99

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26    99  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06    99  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05    99  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04    99  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03    99  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02    99  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
data.iloc[1,0]=0

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06    99  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05    99  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04    99  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03    99  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02    99  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %% [markdown]
# #### 排序

# %%
# 按字段排序
data.sort_values(by=["high"], ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10    99  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12    99  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31    99  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15    99  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11    99  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %%
#按照多字段排序
data.sort_values(by=["high","close"], ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10    99  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12    99  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31    99  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15    99  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11    99  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %%
# 按照索引排序
data.sort_index().head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02    99  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03    99  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04    99  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05    99  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06    99  14.48  14.28  13.13  179831.72          1.12      8.51
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# 2015-03-04      2.30
# 2015-03-05      3.19
# 2015-03-06      6.16

# %%
sr=data["p_change"]

# %%
sr.sort_values(ascending=False) #  默认升序  设置为false则降序排序了
# Out:
# 2015-08-28    10.03
# 2015-05-21    10.02
# 2016-12-22    10.02
# 2015-08-04    10.02
# 2016-07-07    10.02
#               ...
# 2015-08-26   -10.01
# 2015-07-15   -10.02
# 2016-01-11   -10.02
# 2015-09-14   -10.02
# 2015-09-01   -10.03
# Name: p_change, Length: 643, dtype: float64

# %%
sr.sort_index().head()
# Out:
# 2015-03-02    2.62
# 2015-03-03    1.44
# 2015-03-04    1.57
# 2015-03-05    2.02
# 2015-03-06    8.51
# Name: p_change, dtype: float64

# %% [markdown]
# #### DataFrame运算
#    - 算术运算
#    - 逻辑运算
#       - 逻辑运算符
#         -   布尔索引
#       -  逻辑运算函数
#          -   query()
#          -   isin()
#    - 统计运算
#        - min max mean median var std
#        - np.argmax()
#        - np.argmin()
#    - 自定义运算
#        - apply(func, axis=0)True
#            - func:自定义函数

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06    99  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05    99  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04    99  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03    99  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02    99  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
# 算术运算 
data["open"]+3
# Out:
# 2018-02-27    102
# 2018-02-26      3
# 2018-02-23    102
# 2018-02-22    102
# 2018-02-14    102
#              ...
# 2015-03-06    102
# 2015-03-05    102
# 2015-03-04    102
# 2015-03-03    102
# 2015-03-02    102
# Name: open, Length: 643, dtype: int64

# %%
data["open"].add(3).head()# 方便使用head查看
# Out:
# 2018-02-27    102
# 2018-02-26      3
# 2018-02-23    102
# 2018-02-22    102
# 2018-02-14    102
# Name: open, dtype: int64

# %%
data.sub(5).head() # 所有都减5
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    94  20.88  19.16  18.53  95573.03         -4.37     -2.32
# 2018-02-26    -5  18.78  18.53  17.80  60980.11         -4.31     -1.98
# 2018-02-23    94  18.37  17.82  17.71  52909.01         -4.46     -2.58
# 2018-02-22    94  17.76  17.28  17.02  36100.01         -4.64     -3.36
# 2018-02-14    94  16.99  16.92  16.48  23326.04         -4.56     -2.95
#
#             turnover
# 2018-02-27     -2.61
# 2018-02-26     -3.47
# 2018-02-23     -3.68
# 2018-02-22     -4.10
# 2018-02-14     -4.42

# %% [markdown]
# #### 逻辑运算符  <、 >、|、 &

# %%
# 例如筛选p_change > 2的日期数据
data[data["p_change"] > 2].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14    99  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12    99  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 完成一个多个逻辑判断， 筛选p_change > 2并且low > 15
data[(data["p_change"] > 2) & (data["low"] > 15)].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14    99  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12    99  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %% [markdown]
# #### 逻辑运算函数

# %%
# query（expr）   expr为查询字符串
data.query("p_change > 2 & low > 15").head() # 通过query使得运算的过程更加方便简单
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14    99  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12    99  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 判断'turnover'是否为4.19, 2.39
# isin(values)
data[data["turnover"].isin([4.19, 2.39])]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53   95578.03          0.63      2.68
# 2017-07-25    99  24.20  23.70  22.64  167489.48          0.67      2.91
# 2016-09-28    99  20.98  20.86  19.71   95580.75          0.98      4.93
# 2015-04-07    99  17.98  17.54  16.50  122471.85          0.88      5.28
#
#             turnover
# 2018-02-27      2.39
# 2017-07-25      4.19
# 2016-09-28      2.39
# 2015-04-07      4.19

# %% [markdown]
# #### 统计运算
# ![20221011082527.png](./img/20221011082527.png)

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean    98.846034   21.900513   21.336267   20.771835   99905.519114
# std      3.904179    4.077578    3.942806    3.791968   73879.119354
# min      0.000000   12.670000   12.360000   12.200000    1158.120000
# 25%     99.000000   19.500000   19.045000   18.525000   48533.210000
# 50%     99.000000   21.970000   21.450000   20.980000   83175.930000
# 75%     99.000000   24.065000   23.415000   22.850000  127580.055000
# max     99.000000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change    turnover
# count    643.000000  643.000000  643.000000
# mean       0.018802    0.190280    2.936190
# std        0.898476    4.079698    2.079375
# min       -3.520000  -10.030000    0.040000
# 25%       -0.390000   -1.850000    1.360000
# 50%        0.050000    0.260000    2.500000
# ...

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data.max(axis=0) # 按列求最大值
# Out:
# open                99.00
# high                36.35
# close               35.21
# low                 34.01
# volume          501915.41
# price_change         3.03
# p_change            10.03
# turnover            12.56
# dtype: float64

# %%
data.idxmax(axis=0) # 最大值所在的索引
# Out:
# open            2018-02-27
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %% [markdown]
# #### 累计统计函数
# ![](./img/20221011082919.png)

# %%
data["p_change"].cumsum()
# Out:
# 2018-02-27      2.68
# 2018-02-26      5.70
# 2018-02-23      8.12
# 2018-02-22      9.76
# 2018-02-14     11.81
#                ...
# 2015-03-06    114.70
# 2015-03-05    116.72
# 2015-03-04    118.29
# 2015-03-03    119.73
# 2015-03-02    122.35
# Name: p_change, Length: 643, dtype: float64

# %%
data["p_change"].cumsum().plot() # pandas也可画图 图已经出来了 但是 时间没对齐
# Out:
# <AxesSubplot:>

# %%
data["p_change"].sort_index().cumsum().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 自定义运算
# ![](./img/20221011083350.png)

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27    99  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26     0  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23    99  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22    99  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14    99  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06    99  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05    99  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04    99  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03    99  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02    99  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
data.apply(lambda x : x.max()-x.min()) # 拉姆达表达式 最大减最小
# Out:
# open                99.00
# high                23.68
# close               22.85
# low                 21.81
# volume          500757.29
# price_change         6.55
# p_change            20.06
# turnover            12.52
# dtype: float64

# %%
#  检验一下
data["volume"].max()-data["volume"].min()
# Out:
# 500757.29

# %% [markdown]
# #### Pandas画图
#    - sr.plot()
# ![](./img/20221011083928.png)

# %%
data.plot(x="volume", y="turnover", kind="scatter")
# Out:
# <AxesSubplot:xlabel='volume', ylabel='turnover'>

# %%
data.plot(x="high", y="low", kind="scatter")
# Out:
# <AxesSubplot:xlabel='high', ylabel='low'>

# %%
data.plot(x="p_change",y="price_change",kind="scatter")
# Out:
# <AxesSubplot:xlabel='p_change', ylabel='price_change'>

# %% [markdown]
# #### 文件读取与存储
#    1. CSV
#       - pd.read_csv(path)
#          - usecols=
#          - names=
#       - dataframe.to_csv(path)
#          - columns=[]
#          - index=False
#          - header=False
#    2. HDF5
#       - hdf5 存储 3维数据的文件
#          - key1 dataframe1二维数据
#          - key2 dataframe2二维数据
#       - pd.read_hdf(path, key=)
#       - df.to_hdf(path, key=)
#    3. JSON
#       -  pd.read_json(path)
#          - orient="records"
#          - lines=True
#        - df.to_json(patn)
#          - orient="records"
#          - lines=True
#
# ![](./img/20221011084457.png)

# %% [markdown]
# #### 读取csv文件 -read_csv()

# %%
# usecols 读取需要的列
pd.read_csv("./stock_day/stock_day.csv",usecols=["high","low","open"])
# Out:
#              open   high    low
# 2018-02-27  23.53  25.88  23.53
# 2018-02-26  22.80  23.78  22.80
# 2018-02-23  22.88  23.37  22.71
# 2018-02-22  22.25  22.76  22.02
# 2018-02-14  21.49  21.99  21.48
# ...           ...    ...    ...
# 2015-03-06  13.17  14.48  13.13
# 2015-03-05  12.88  13.45  12.87
# 2015-03-04  12.80  12.92  12.61
# 2015-03-03  12.52  13.06  12.52
# 2015-03-02  12.25  12.67  12.20
#
# [643 rows x 3 columns]

# %%
# 文件没有列 直接就是数据 需要加上字段
pd.read_csv("stock_day2.csv",names=["open", "high", "close", "low", "volume", "price_change", "p_change", "ma5", "ma10", "ma20", "v_ma5", "v_ma10", "v_ma20", "turnover"])
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %% [markdown]
# #### 写入csv文件 -to_csv()
# ![](./img/20221011085158.png)

# %%
# 保存'open'列的数据
data[:10].to_csv("save_open.csv", columns=["open"])

# %%
pd.read_csv("save_open.csv")
# Out:
#    index_time  open
# 0  2018-02-27    99
# 1  2018-02-26     0
# 2  2018-02-23    99
# 3  2018-02-22    99
# 4  2018-02-14    99
# 5  2018-02-13    99
# 6  2018-02-12    99
# 7  2018-02-09    99
# 8  2018-02-08    99
# 9  2018-02-07    99

# %%
data[:10].to_csv("save_open.csv", columns=["open"], index=False, mode="a", header=False)

# %%
pd.read_csv("save_open.csv")
# Out:
#     index_time  open
# 0   2018-02-27  99.0
# 1   2018-02-26   0.0
# 2   2018-02-23  99.0
# 3   2018-02-22  99.0
# 4   2018-02-14  99.0
# 5   2018-02-13  99.0
# 6   2018-02-12  99.0
# 7   2018-02-09  99.0
# 8   2018-02-08  99.0
# 9   2018-02-07  99.0
# 10          99   NaN
# 11           0   NaN
# 12          99   NaN
# 13          99   NaN
# 14          99   NaN
# 15          99   NaN
# 16          99   NaN
# 17          99   NaN
# 18          99   NaN
# 19          99   NaN

# %% [markdown]
# #### HDF5
